# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from plotly import express as px


import seaborn as sns


plt.style.use('seaborn')

# %%
df=pd.read_csv('hotel_bookings.csv')
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ## Outliers

# %% [markdown]
# Outliers are extremely large or small values relative to the other points of dataset. I will use box plots and histograms to visualize the distribution of the data and detect outliers.

# %%
features = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'adr', 'days_in_waiting_list']
#Creating a boxplot and a histogram for outlier detection

n = 1

sns.set_style('whitegrid')
sns.set(font_scale = 1.2)
plt.figure(figsize = (16, 100))

for feature in features:
    plt.subplot(15,2,n)
    sns.boxplot(df[feature], palette = 'autumn').set(xlabel = None)
    plt.title(f'{feature} boxplot')
    n = n + 1
    
    plt.subplot(15,2,n)
    plt.hist(df[feature], color = '#f7b267')
    plt.title(f'{feature} histogram')
    n = n + 1
    plt.tight_layout()

# %%
# Using loc[] to set new values for outliers
#将异常值换做了最大值
df.loc[df['lead_time']                      > 380, ['lead_time']                   ] = 380
df.loc[df['stays_in_weekend_nights']        > 6, ['stays_in_weekend_nights']       ] = 6
df.loc[df['stays_in_week_nights']           > 10, ['stays_in_week_nights']         ] = 10
df.loc[df['adults']                         > 4, ['adults']                        ] = 4
df.loc[df['children']                       > 8, ['lead_time']                     ] = 0
df.loc[df['babies']                         > 8, ['babies']                        ] = 0
df.loc[df['booking_changes']                > 5, ['booking_changes']               ] = 5
df.loc[df['days_in_waiting_list']           > 0, ['days_in_waiting_list']          ] = 1
df.loc[df['previous_cancellations']         > 0, ['previous_cancellations']        ] = 1
df.loc[df['previous_bookings_not_canceled'] > 0, ['previous_bookings_not_canceled']] = 1

# %%
features = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'adr', 'days_in_waiting_list']
#Creating a boxplot and a histogram for outlier detection

n = 1

sns.set_style('whitegrid')
sns.set(font_scale = 1.2)
plt.figure(figsize = (16, 100))

for feature in features:
    plt.subplot(15,2,n)
    sns.boxplot(df[feature], palette = 'autumn').set(xlabel = None)
    plt.title(f'{feature} boxplot')
    n = n + 1
    
    plt.subplot(15,2,n)
    plt.hist(df[feature], color = '#f7b267')
    plt.title(f'{feature} histogram')
    n = n + 1
    plt.tight_layout()

# %% [markdown]
# ## Duplicated data

# %%
# Counting duplicate data in dataframe

df.duplicated().sum()
# Out:
# 32036

# %%
# Dropping duplicate rows

df.drop_duplicates(inplace = True)

# %%
df.dropna(subset=['company'],axis=0,inplace=True)

# %%
df.dropna(subset=['children'],axis=0,inplace=True)

# %%
df.agent.fillna('No agent',inplace=True)

# %%
df.country.fillna('Unknown',inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# hotel                             0
# is_canceled                       0
# reservation_status                0
# total_of_special_requests         0
# required_car_parking_spaces       0
# adr                               0
# customer_type                     0
# days_in_waiting_list              0
# company                           0
# agent                             0
# deposit_type                      0
# booking_changes                   0
# assigned_room_type                0
# reserved_room_type                0
# previous_bookings_not_canceled    0
# previous_cancellations            0
# is_repeated_guest                 0
# distribution_channel              0
# market_segment                    0
# country                           0
# meal                              0
# babies                            0
# children                          0
# adults                            0
# stays_in_week_nights              0
# stays_in_weekend_nights           0
# ...

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 18      Resort Hotel            0          0               2015
# 218     Resort Hotel            1          1               2015
# 220     Resort Hotel            0          1               2015
# 295     Resort Hotel            0         84               2015
# 387     Resort Hotel            0          1               2015
# ...              ...          ...        ...                ...
# 119117    City Hotel            0         39               2017
# 119118    City Hotel            0          1               2017
# 119119    City Hotel            0         40               2017
# 119124    City Hotel            0          0               2017
# 119248    City Hotel            0         22               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 18                   July                        27
# 218                  July                        28
# ...

# %%
confirmed_bookings = df[df['is_canceled'] ==0]
confirmed_bookings
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df['kids'] = df['children'] + df['babies']
df['family'] = np.where(df['kids'] > 0, '1', '0')
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ## 市场渠道饼状图

# %%
df.market_segment.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='market_segment'>

# %% [markdown]
# ## the visualization of stays

# %%
#取消与不取消与酒店的关系
pd.crosstab(df.hotel,df.is_canceled).plot.bar(color=['#dcb7c8','#7c5acb'])
plt.xticks(rotation=0)
plt.show()

# %%
pd.crosstab(df.hotel,df.reserved_room_type).plot.bar(color=['#dcb7c8','#7c5acb'])
# Out:
# <AxesSubplot:xlabel='hotel'>

# %%
df_cancel = pd.crosstab(df.hotel,df.is_canceled,margins=True)
df_cancel['cancel_percent']=df_cancel[1]*100/df_cancel['All']
df_cancel
# Out:
# is_canceled      0    1   All  cancel_percent
# hotel
# City Hotel    2431  338  2769       12.206573
# Resort Hotel  2236  234  2470        9.473684
# All           4667  572  5239       10.918114

# %%
pd.crosstab(df.arrival_date_month,df.hotel).plot.bar(color=['#dcb7c8','#7c5acb'])
plt.title('Monthwise Number of Bookings ')
plt.xlabel('Booking Month')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=60,ha='right')
plt.show()

# %%
#去效率与预订天数
df_cancel = pd.crosstab(df.lead_time,df.is_canceled,margins=True)
df_cancel['cancel_percent']=df_cancel[1]*100/df_cancel['All']
df_cancel.drop('All',axis=1,inplace=True)
df_cancel.drop('All',axis=0,inplace=True)
df_cancel
# Out:
# is_canceled    0   1  cancel_percent
# lead_time
# 0            716  54        7.012987
# 1            408  41        9.131403
# 2            291  30        9.345794
# 3            258  36       12.244898
# 4            250  24        8.759124
# ...          ...  ..             ...
# 360            3   0        0.000000
# 362            1   0        0.000000
# 363            5   0        0.000000
# 364           51   2        3.773585
# 365           10   0        0.000000
#
# [198 rows x 3 columns]

# %%
df_cancel['cancel_percent'].plot()
plt.title('Cancellation Rate across Hotel Type')
plt.xlabel('Lead Time')
plt.xticks(rotation=0)
plt.ylabel('Cancellation %')
plt.show()

# %%
df_cancel['cancel_percent'].plot()
plt.title('Cancellation Rate across Hotel Type')
plt.xlabel('Lead Time')
plt.xticks(rotation=0)
plt.ylabel('Cancellation %')
plt.show()

# %%
df['is_canceled'].astype('str')
# Out:
# 18        0
# 218       1
# 220       0
# 295       0
# 387       0
#          ..
# 119117    0
# 119118    0
# 119119    0
# 119124    0
# 119248    0
# Name: is_canceled, Length: 5239, dtype: object

# %%
#是否提交了押金

df['is_canceled']=df['is_canceled'].astype('str')
canceled_bookings = df[df['is_canceled'] == '1']

fig, ax = plt.subplots(figsize = (10, 5))



sns.countplot(ax = ax, y = 'deposit_type', data = canceled_bookings, orient = "h" ,palette = 'BuPu').set(ylabel = None)
ax.bar_label(ax.containers[0], padding = 4)
plt.title('Deposit type of cancelled bookings')

plt.show()

# %%
#取消率与年份的柱状图
fig, ax = plt.subplots(figsize = (8, 5))

sns.countplot(x='arrival_date_year',data=df,hue='hotel')
plt.xlabel('Year')
plt.ylabel('Number of Bookings')
plt.title('Hotel Wise booking each year')
plt.show()

# %% [markdown]
# From the above barplots we see that 2016 had the highest number of bookings. While 2015 had the least. This could imply that these hotels could newer and established around 2015

# %%
tbl3=pd.crosstab(df.arrival_date_month,df.is_canceled,margins=True)
tbl3['cancel-percent']=tbl3[1]*100/tbl3['All']
tbl3['cancel-percent']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/ds/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/envs/ds/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/ds/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df1=df[df['customer_type']=='Transient']
df1_cancel = pd.crosstab(df1.arrival_date_month,df1.is_canceled,margins=True)
df1_cancel['cancel_percent']=df1_cancel[1]*100/df1_cancel['All']
df1_cancel.drop('All',axis=1,inplace=True)
df1_cancel.drop('All',axis=0,inplace=True)
df1_cancel=df1_cancel.reindex(['January','February','March','April','May','June','July','August','September',
'October','November','December'])
df1_cancel.reset_index()
# Out:
# is_canceled arrival_date_month   0.0   1.0  cancel_percent
# 0                      January  3005   957       24.154467
# 1                     February  3943  1293       24.694423
# 2                        March  4593  1675       26.723038
# 3                        April  4306  2219       34.007663
# 4                          May  4594  2234       32.718219
# 5                         June  4386  2206       33.464806
# 6                         July  5718  2963       34.132012
# 7                       August  6227  3339       34.904871
# 8                    September  3308  1323       28.568344
# 9                      October  3589  1309       26.725194
# 10                    November  3202   896       21.864324
# 11                    December  3047  1218       28.558030

# %%
sns.lineplot(
    x='arrival_date_month',
    y='cancel_percent',
    data=df1_cancel,
    ci =None, 
    palette = 'viridis', 
    alpha = 0.6,
)

# %% [markdown]
# ### 取消率与年份的关系

# %%
tbl=pd.crosstab(df.arrival_date_month,df.is_canceled,margins=True)
tbl
# Out:
# is_canceled             0      1    All
# arrival_date_month
# April                5465   2401   7866
# August               7613   3618  11231
# December             3706   1373   5079
# February             4625   1413   6038
# January              3598   1037   4635
# July                 6832   3189  10021
# June                 5399   2352   7751
# March                5626   1829   7455
# May                  5897   2442   8339
# November             3899   1052   4951
# October              5245   1634   6879
# September            5021   1632   6653
# All                 62926  23972  86898

# %%
tbl['cancel-percent']=tbl[1]*100/tbl['All']
tbl.drop('All',inplace=True)

# %%
tbl['cancel-percent'].plot.bar()
plt.xticks(rotation=0)
plt.xlabel('Year')
plt.ylabel('Cancellation %')
plt.title('Cancellation rates across 2015-2017')
plt.show()

# %%
tbl2=pd.crosstab(df.required_car_parking_spaces,df.is_canceled,margins=True)
tbl2['cancel-percent']=tbl2[1]*100/tbl2['All']
tbl2.drop('All',inplace=True)
tbl2
# Out:
# is_canceled                      0      1    All  cancel-percent
# required_car_parking_spaces
# 0                            55722  23972  79694       30.080056
# 1                             7171      0   7171        0.000000
# 2                               28      0     28        0.000000
# 3                                3      0      3        0.000000
# 8                                2      0      2        0.000000

# %%
tbl2['cancel-percent'].plot.bar()
plt.xticks(rotation=0)
plt.xlabel('required_car_parking_spaces')
plt.ylabel('Cancellation %')
plt.title('Cancellation rates about car parking')
plt.show()

# %%
tbl3=pd.crosstab(df.meal,df.is_canceled,margins=True)
tbl3['cancel-percent']=tbl3[1]*100/tbl3['All']
tbl3.drop('All',inplace=True)
tbl3
# Out:
# is_canceled      0      1    All  cancel-percent
# meal
# BB           49519  18007  67526       26.666765
# FB             261     97    358       27.094972
# HB            6608   2444   9052       26.999558
# SC            6132   3342   9474       35.275491
# Undefined      406     82    488       16.803279

# %%
tbl3['cancel-percent'].plot.bar()
plt.xticks(rotation=0)
plt.xlabel('meal')
plt.ylabel('Cancellation %')
plt.title('Cancellation rates about meal type')
plt.show()

# %%
fig, ax =plt.subplots(figsize=(15, 5))
confirmed_bookings = df[df['is_canceled'] == 0]


months = confirmed_bookings['arrival_date_month'].unique()
sns.lineplot(x = 'arrival_date_month', y = 'adr', hue = 'hotel', data = confirmed_bookings, ci =None, palette = 'viridis', alpha = 0.6)
plt.title('Monthly ADR')
plt.xlabel('Months')
plt.xticks(ticks = [m for m in months])

plt.tight_layout()
# Out:
# /var/folders/p4/5cygqf1s7yq7cpqb6bx0sbrc0000gn/T/ipykernel_19960/239045764.py:6: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.

# %%
(df['arrival_date_month'].unique()).size
# Out:
# 12

# %%
fig, ax =plt.subplots(figsize=(15, 8))
confirmed_bookings = df[df['is_canceled'] == 0]

rh = confirmed_bookings[confirmed_bookings['hotel'] == 'Resort Hotel']
ch = confirmed_bookings[confirmed_bookings['hotel'] == 'City Hotel']

rh1 = rh.groupby('arrival_date_month')['adr'].mean()
order=['July','August','September','October','November','December','January','February','March','April','May','June',]
rh1 =rh1[order]
rh1
rh1.plot().set_xticks(range(12),df.arrival_date_month.unique(),rotation=60)

ch1 = ch.groupby('arrival_date_month')['adr'].mean()
order=['July','August','September','October','November','December','January','February','March','April','May','June',]
ch1 =ch1[order]
ch1.plot().set_xticks(range(12),df.arrival_date_month.unique(),rotation=60)

# %%
import seaborn as sns

sns.catplot(
    data=data,
    kind='box',
    x='reserved_room_type',
    y='adr',
    hue='hotel',
    palette='Blues_d'
)
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize=(5,5))
df['hotel'].value_counts().plot.pie()
plt.title('Distribution of the type of Hotel')
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize=(5,5))
ax1.pie(df.meal.value_counts().values,explode=[0.1,0.1,0.1,1,0.1],labels=df.meal.value_counts().index,autopct='%.2f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
#pic7
df['arrival_date'] = df['arrival_date_month'] + " " + df['arrival_date_day_of_month'].astype(str) + " " + df['arrival_date_year'].astype(str)
df['arrival_date'] = pd.to_datetime(df['arrival_date'])


monthly = df.groupby(pd.Grouper(key='arrival_date', axis=0, 
                      freq='M')).sum()

sns.set(rc={'figure.figsize':(14,11)})
g = sns.lineplot(ax=ax[2,0],x="arrival_date", y="required_car_parking_spaces",data=monthly)
g.set(title="Monthly Required Parking Spaces")
g.set_xlabel("Month", fontsize = 14)
g.set_ylabel("Parking Spaces Required", fontsize = 14)

#pic8
sns.countplot(ax=ax[2,1],x='arrival_date_month',data=df,order=df.arrival_date_month.value_counts().index)
plt.title('Monthwise Number of Bookings ')
plt.xlabel('Booking Month')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=60,ha='right')

#pic9
plt.figure(figsize=(10,10))
sns.countplot(ax=ax[2,2],x='total_of_special_requests', data=df, palette = 'ocean_r')
plt.title('Total Special Request', weight='bold')
plt.xlabel('Number of Special Request', fontsize=12)
plt.ylabel('Count', fontsize=12)

# %%
df['meal'].value_counts().plot.pie()
plt.title('Distribution of the type of Hotel')
plt.show()

# %%
plt.figure(figsize = (10, 5))

data = confirmed_bookings['is_repeated_guest'].value_counts()
colors = sns.color_palette('Paired')
labels = ['new guest', 'repeated guest']

plt.pie(data, labels = labels, autopct = '%.0f%%', colors = colors)
plt.title('Bookings by new and repeated guest')

plt.tight_layout()

# %%
plt.figure(figsize = (10, 5))

sns.countplot(x = 'hotel', data = df, hue = 'is_canceled', palette = 'magma_r', alpha = 0.8).set(xlabel = None)
plt.title('Cancelation rates by hotel')

plt.tight_layout()

# %%
plt.figure(figsize = (14, 5))

sns.displot(confirmed_bookings, x = 'customer_type', hue = 'hotel', multiple = 'stack', palette = 'Purples', alpha = 0.8).set(xlabel = None)
plt.title('Customer type by hotel')

plt.tight_layout()

# %%
df['kids'] = df['children'] + df['babies']
df['family'] = np.where(df['kids'] > 0, '1', '0')
df
confirmed_bookings = df[df['is_canceled'] == 0]
confirmed_bookings
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
plt.figure(figsize = (10, 5))

palette = ["#457b9d", "#a8dadc"]

sns.countplot(data = confirmed_bookings, x = 'hotel', hue = 'family', palette = palette, alpha = 0.8).set(xlabel = None)
plt.title('Families by hotel')

plt.tight_layout()

# %%
df['arrival_date'] = df['arrival_date_month'] + " " + df['arrival_date_day_of_month'].astype(str) + " " + df['arrival_date_year'].astype(str)
df['arrival_date'] = pd.to_datetime(df['arrival_date'])


monthly = df.groupby(pd.Grouper(key='arrival_date', axis=0, 
                      freq='M')).sum()

sns.set(rc={'figure.figsize':(14,11)})
g = sns.lineplot(x="arrival_date", y="required_car_parking_spaces",data=monthly)
g.set(title="Monthly Required Parking Spaces")
g.set_xlabel("Month", fontsize = 14)
g.set_ylabel("Parking Spaces Required", fontsize = 14)
# Out:
# Text(0, 0.5, 'Parking Spaces Required')

# %%
plt.rcParams['figure.figsize']=[8,5]
sns.countplot(x='arrival_date_month',data=df,order=df.arrival_date_month.value_counts().index)
plt.title('Monthwise Number of Bookings ')
plt.xlabel('Booking Month')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=60,ha='right')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='total_of_special_requests', data=df, palette = 'ocean_r')
plt.title('Total Special Request', weight='bold')
plt.xlabel('Number of Special Request', fontsize=12)
plt.ylabel('Count', fontsize=12)
# Out:
# Text(0, 0.5, 'Count')
